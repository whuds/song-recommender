# %% [markdown]
# # K-Nearest Neighbors approach

# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# ### Load Data

# %%
spotify_data = pd.read_csv('spotify_audio_features.csv', header=0)

#debugging output, uncomment to view data
#spotify_data.head

# %% [markdown]
# ### Removing Duplicates

# %%
#default duplicate removal
#748411 results
spotify_data_df = spotify_data.drop_duplicates()

#I ran into issues using just the default above because some of the names were different even though they were the same song 
# i.e. https://ibb.co/JKvZ2Qn so instead if they have the same few features, we'll drop based on those
#482288 results
spotify_data_df = spotify_data.drop_duplicates(subset=['rank', 'danceability','energy','key','loudness','liveness','valence'])

#reset the index
spotify_data_df = spotify_data_df.reset_index(drop=True)

#debugging output, uncomment to view
#spotify_data_df.head

# %% [markdown]
# ### Extract Relevant Features

# %%
#messing around with this to try and give better results
relevant_features = ['rank', 'danceability','energy','key','loudness','liveness','valence']
relevant_features = ['rank', 'danceability','energy','loudness','liveness']

train_data = spotify_data_df[relevant_features]

#debugging output, uncomment to view
#train_data.head

# %% [markdown]
# ## Create Model
# ### Nearest Neighbors

# %%
#create Nearest Neighbors model and fit data
neigh = NearestNeighbors(10)
neigh.fit(train_data)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='minkowski',
#                  metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                  radius=1.0)

# %% [markdown]
# ### Pick a Song

# %%
#pick a random song
rand_song = spotify_data_df.sample(n=1)
rand_song_feat = rand_song[relevant_features]

# %%
neigh_ind = neigh.kneighbors(rand_song_feat, return_distance=False)

# %% [markdown]
# ### Input Song

# %%
rand_song[['name', 'artist_name', 'tag_name', 'rank', 'danceability','energy','key','loudness','liveness','valence']]
# Out:
#                            name artist_name tag_name   rank  danceability  \
# 370603  Psy Z Lasu Śpiewającego        Eldo  Hip-Hop  0.756         0.605
#
#         energy    key  loudness  liveness  valence
# 370603      11 -8.514         1     0.651   90.031

# %% [markdown]
# ### Closest Songs

# %%
closest_songs = spotify_data_df.iloc[ neigh_ind[0] , : ]

closest_songs[['name', 'artist_name', 'tag_name', 'rank', 'danceability','energy','key','loudness','liveness','valence']]
# Out:
#                                 name                artist_name      tag_name  \
# 370603       Psy Z Lasu Śpiewającego                       Eldo       Hip-Hop
# 53349                       Żyrandol             Taco Hemingway     seen live
# 351594               I Had It Coming              White Rabbits    indie rock
# 58794                         Issook  De Jeugd van Tegenwoordig     seen live
# 295562               Never Say Never             Edward Ka-Spel  experimental
# 83845        Glass Houses - Acoustic                  The Beach   alternative
# 370866                      Airplane                   Curren$y       Hip-Hop
# 468660  Walk Like An Egyptian (1986)                The Bangles           80s
# 37538       Render Me - Andrés Remix                 Mr. Scruff    electronic
# 97342                     Durchreise                       Fink         indie
#
#          rank  danceability  energy     key  loudness  liveness  valence
# 370603  0.756         0.605      11  -8.514         1     0.651   90.031
# 53349   0.755         0.584      11  -9.987         1     0.657   80.094
# 351594  0.751         0.591      11  -7.645         1     0.670   92.012
# 58794   0.744         0.607      11  -9.170         1     0.629  120.052
# 295562  0.750         0.579      11  -9.644         1     0.643  120.024
# 83845   0.768         0.579      11  -9.481         1     0.660  123.966
# 370866  0.756         0.638      11  -8.738         1     0.644   79.054
# 468660  0.760         0.641      11 -13.904         1     0.629  104.001
# 37538   0.744         0.567      11 -11.926         1     0.674  117.483
# 97342   0.717         0.602      11  -9.265         1     0.626   92.017

# %% [markdown]
# ### To Do
#
# Use the 'tag_name' feature in distance calculation (if one song is a singer-songwriter song, my personal opinion is that we should weight that in the model also, returning more )

# %% [markdown]
# # =========================================================
# # =========================================================
# # =========================================================
# # =========================================================
# # =========================================================
# # =========================================================
#
# # Combining Datasets
#
# We need to come up with a way to link the User from the User/Artists Last FM dataset to the Songs/Features Spotify dataset. The method here finds the most popular songs of each artist and uses that to establish a connection between Users and Songs.

# %%
# sort by artist and playcount, so we'll have the top songs for each artist 
spotify_data_df.sort_values(by=['artist_name','playcount'], inplace=True, ascending=False)

# %%
#set the artist_name as index
spotify_data_df.set_index(keys=['artist_name'], drop=False,inplace=True)

#get all the artist_names as a list
artist_names = spotify_data_df['artist_name'].unique().tolist()

#debugging output
#spotify_data_df

# %% [markdown]
# ## Get the 5 most played song for each artist

# %%
#this takes some time
artist_data = pd.concat([pd.DataFrame(spotify_data_df.loc[artist][:5], columns=spotify_data_df.columns) for artist in artist_names], ignore_index=True)

#debugging output
#artist_data

# %% [markdown]
# ### Confirming that the 5 largest were found

# %%
spotify_data_df.loc['Coldplay'].nlargest(5,columns='playcount')
# Out:
#                                        name tag_name  playcount  listeners  \
# artist_name
# Coldplay                     Moving to Mars     rock     199515      24623
# Coldplay               The Scientist (live)     rock     167650      23401
# Coldplay                            M.M.I.X     rock     165690      26280
# Coldplay     Prospekt's March / Poppyfields     rock     143545      24042
# Coldplay                 Life Is for Living     rock     141846      24942
#
#             artist_name   rank  danceability  energy     key  loudness  ...  \
# artist_name                                                             ...
# Coldplay       Coldplay  0.263        0.3150       8 -10.797         1  ...
# Coldplay       Coldplay  0.294        0.6520       5  -7.314         1  ...
# Coldplay       Coldplay  0.175        0.0613       4 -29.286         1  ...
# Coldplay       Coldplay  0.227        0.2790       2 -11.992         1  ...
# Coldplay       Coldplay  0.374        0.4560       6  -7.352         0  ...
#
#              liveness  valence           tempo                    type  \
# artist_name
# Coldplay       0.1960  142.657  audio_features  0kuv7BqWNDprDao3Tb5flN
# Coldplay       0.1670   75.335  audio_features  1aZhbOdRqshLS6uPjiO8Y4
# Coldplay       0.1570  126.842  audio_features  5Y7ztPw93VbAle55brM0jo
# Coldplay       0.0954  154.465  audio_features  4yr1059N96a8msTHVftmFN
# Coldplay       0.0753  135.645  audio_features  1RNtm45kw0hPMBz7gKiIYu
#
#                                                id  \
# artist_name
# Coldplay     spotify:track:0kuv7BqWNDprDao3Tb5flN
# Coldplay     spotify:track:1aZhbOdRqshLS6uPjiO8Y4
# Coldplay     spotify:track:5Y7ztPw93VbAle55brM0jo
# Coldplay     spotify:track:4yr1059N96a8msTHVftmFN
# Coldplay     spotify:track:1RNtm45kw0hPMBz7gKiIYu
#
#                                                            uri  \
# artist_name
# Coldplay     https://api.spotify.com/v1/tracks/0kuv7BqWNDpr...
# Coldplay     https://api.spotify.com/v1/tracks/1aZhbOdRqshL...
# Coldplay     https://api.spotify.com/v1/tracks/5Y7ztPw93VbA...
# Coldplay     https://api.spotify.com/v1/tracks/4yr1059N96a8...
# Coldplay     https://api.spotify.com/v1/tracks/1RNtm45kw0hP...
#
#                                                     track_href analysis_url  \
# artist_name
# Coldplay     https://api.spotify.com/v1/audio-analysis/0kuv...       258874
# Coldplay     https://api.spotify.com/v1/audio-analysis/1aZh...       388600
# Coldplay     https://api.spotify.com/v1/audio-analysis/5Y7z...        48466
# Coldplay     https://api.spotify.com/v1/audio-analysis/4yr1...       219231
# Coldplay     https://api.spotify.com/v1/audio-analysis/1RNt...       436440
#
#             duration_ms time_signature
# artist_name
# Coldplay              4            NaN
# Coldplay              4            NaN
# Coldplay              3            NaN
# Coldplay              4            NaN
# Coldplay              4            NaN
#
# [5 rows x 24 columns]

# %%
artist_data.loc[artist_data['artist_name'] == 'Coldplay']
# Out:
#                                  name tag_name playcount listeners  \
# 24794                  Moving to Mars     rock    199515     24623
# 24795            The Scientist (live)     rock    167650     23401
# 24796                         M.M.I.X     rock    165690     26280
# 24797  Prospekt's March / Poppyfields     rock    143545     24042
# 24798              Life Is for Living     rock    141846     24942
#
#       artist_name   rank  danceability energy     key loudness  ...  liveness  \
# 24794    Coldplay  0.263        0.3150      8 -10.797        1  ...    0.1960
# 24795    Coldplay  0.294        0.6520      5  -7.314        1  ...    0.1670
# 24796    Coldplay  0.175        0.0613      4 -29.286        1  ...    0.1570
# 24797    Coldplay  0.227        0.2790      2 -11.992        1  ...    0.0954
# 24798    Coldplay  0.374        0.4560      6  -7.352        0  ...    0.0753
#
#        valence           tempo                    type  \
# 24794  142.657  audio_features  0kuv7BqWNDprDao3Tb5flN
# 24795   75.335  audio_features  1aZhbOdRqshLS6uPjiO8Y4
# 24796  126.842  audio_features  5Y7ztPw93VbAle55brM0jo
# 24797  154.465  audio_features  4yr1059N96a8msTHVftmFN
# 24798  135.645  audio_features  1RNtm45kw0hPMBz7gKiIYu
#
#                                          id  \
# 24794  spotify:track:0kuv7BqWNDprDao3Tb5flN
# 24795  spotify:track:1aZhbOdRqshLS6uPjiO8Y4
# 24796  spotify:track:5Y7ztPw93VbAle55brM0jo
# 24797  spotify:track:4yr1059N96a8msTHVftmFN
# 24798  spotify:track:1RNtm45kw0hPMBz7gKiIYu
#
#                                                      uri  \
# 24794  https://api.spotify.com/v1/tracks/0kuv7BqWNDpr...
# 24795  https://api.spotify.com/v1/tracks/1aZhbOdRqshL...
# 24796  https://api.spotify.com/v1/tracks/5Y7ztPw93VbA...
# 24797  https://api.spotify.com/v1/tracks/4yr1059N96a8...
# 24798  https://api.spotify.com/v1/tracks/1RNtm45kw0hP...
#
#                                               track_href analysis_url  \
# 24794  https://api.spotify.com/v1/audio-analysis/0kuv...       258874
# 24795  https://api.spotify.com/v1/audio-analysis/1aZh...       388600
# 24796  https://api.spotify.com/v1/audio-analysis/5Y7z...        48466
# 24797  https://api.spotify.com/v1/audio-analysis/4yr1...       219231
# 24798  https://api.spotify.com/v1/audio-analysis/1RNt...       436440
#
#       duration_ms time_signature
# 24794           4            NaN
# 24795           4            NaN
# 24796           3            NaN
# 24797           4            NaN
# 24798           4            NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Extract Features

# %%
#get relevant features of the data
artist_data_rel = artist_data [['name', 'artist_name', 'tag_name', 'playcount','rank', 'danceability','energy','key','loudness','liveness','valence']]

#set artist_name column to lowercase to match with the Last FM dataset
artist_data_rel['artist_name'] = artist_data_rel['artist_name'].str.lower()

print(artist_data_rel.shape)
#artist_data_rel.head()

#debugging output
#artist_data_rel.loc[artist_data['artist_name'] == 'Coldplay']
# Out:
# (30177, 11)
# C:\Users\wyndh\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# We can see that in the Spotify dataset above we have the top 5 tracks each from about 6000 artists. (30000 tracks in total)
#
# ## Load in User/Artists from Last FM dataset

# %%
filename ="lastfm-dataset-360k\\usersha1-artmbid-artname-plays.tsv"
user_data = pd.read_csv(filename, sep='\t', header=0)

# %%
user_data.shape
# Out:
# (17535655, 4)

# %% [markdown]
# ### Removing artists that aren't in the Spotify Dataset
#
# We remove the artists that aren't found in the Spotify Dataset because we have no content to compare with for them.

# %%
#remove all artists that aren't in the spotify dataset
artist_names_lower = [artist.lower() for artist in artist_names]
user_data = user_data[user_data['artist-name'].isin(artist_names_lower)]
user_data = user_data.reset_index(drop=True)

user_data.shape
# Out:
# (6977817, 4)

# %%
user_data.head()
# Out:
#                               user-mboxsha1  \
# 0  00000c289a1829a808ac09c00daf10bc3c4e223b
# 1  00000c289a1829a808ac09c00daf10bc3c4e223b
# 2  00000c289a1829a808ac09c00daf10bc3c4e223b
# 3  00000c289a1829a808ac09c00daf10bc3c4e223b
# 4  00000c289a1829a808ac09c00daf10bc3c4e223b
#
#                   musicbrainz-artist-id            artist-name  plays
# 0  b3ae82c2-e60b-4551-a76d-6620f1b456aa      melissa etheridge    897
# 1  8bfac288-ccc5-448d-9573-c33ea2aa5c30  red hot chili peppers    691
# 2  c5db90c4-580d-4f33-b364-fbaa5a3a58b5            the murmurs    424
# 3  7b885d42-3c41-4f43-9944-a5855ec5155e              goldfrapp    361
# 4  7e870dd5-2667-454b-9fcf-a132dd8071f1          jack off jill    316

# %%
#dropping all artists who aren't in the user dataset
users_artist_names = user_data['artist-name'].unique().tolist()
print(len(users_artist_names))

print(artist_data_rel.shape)

artist_data_filtered = artist_data_rel[artist_data_rel['artist_name'].isin(users_artist_names)]

#removing the artists that aren't in the user database removes about 9000 tracks from our set
print(artist_data_filtered.shape)

#debugging output
#artist_data_filtered.loc[artist_data_filtered['artist_name'] == 'melissa etheridge']
# Out:
# 4458
# (30177, 11)
# (21988, 11)

# %% [markdown]
# Here we can merge our datasets aroudnd the artist name and we'll have expanded our dataset to have 5 songs representing each artist that a user has listened to. Then we can find songs for an artist based on their past listening history.

# %%
#merge datasets
user_songs_df = pd.merge(user_data, artist_data_filtered, left_on="artist-name", right_on="artist_name")

#debugging output
#user_songs_df[0:10]

# %%
#creating a artist-tag dictionary because it's helpful to see how predictions compare
artist_tag_dict = dict(zip(user_songs_df.artist_name, user_songs_df.tag_name))

# %%
#Get the unique users
users = user_data['user-mboxsha1'].unique().tolist()

# %% [markdown]
# ## Running KNN again on Users to Predict Songs with Merged Data

# %%
relevant_features = ['rank', 'danceability','liveness']

#create new train data
train_data_2 = artist_data_filtered[relevant_features]

# %%
#need to find which user has the most listened to songs, as we have to find that number + 10 nearest neighbors to avoid duplicates
items_counts = user_songs_df['user-mboxsha1'].value_counts()
max_item = items_counts.max()
print(max_item)
# Out:
# 360

# %%
#create new model
neigh = NearestNeighbors(370)
neigh.fit(train_data_2)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='minkowski',
#                  metric_params=None, n_jobs=None, n_neighbors=370, p=2,
#                  radius=1.0)

# %%
def test_KNN(user=None):
    #choose a random user
    if user==None:
        l = len(users)
        user = users[np.random.randint(l)]
    print("user:",user)
    
    
    #get background on user
    user_background = user_data.loc[user_data['user-mboxsha1'] == user ]
    user_fav = user_background['artist-name'].unique().tolist()
    for fav in user_fav:
        print(fav, "-", artist_tag_dict[fav])
    
    #grab all song data for specific user
    test_user = user_songs_df.loc[user_songs_df['user-mboxsha1'] == user ]
    #get just the features used in training the KNN
    test_user_relevant = test_user[relevant_features]
    #convert to a numpy array to input in KNN
    user_song_feat = test_user_relevant.to_numpy()
    #get index_start to avoid distances of 0 (songs that are already in the database)
    index_start, _ = user_song_feat.shape
    #run KNN
    neigh_ind = neigh.kneighbors(user_song_feat, return_distance=False)

    #return closest songs
    closest_songs = artist_data_filtered.iloc[ neigh_ind[0][index_start:index_start+10] , : ]
    return closest_songs

# %%
#you can run this cell repeatedly to test KNN and view results for a specific user, or leave blank to pick a random user
test_KNN('95c0825905dfdd3db43b7f2051012360f0b14637')
# Out:
# user: 95c0825905dfdd3db43b7f2051012360f0b14637
# ketil bjørnstad - jazz
# max richter - ambient
# liquid mind - ambient
# swod - ambient
# eluvium - ambient
# goldmund - ambient
# sylvain chauveau - ambient
# the boats - ambient
# jóhann jóhannsson - ambient
# boards of canada - ambient
# library tapes - ambient
# stephan micus - ambient
# dntel - electronic
# biosphere - ambient
#                                 name       artist_name           tag_name  \
# 2006                Life as a Flower  vincent diamante       instrumental
# 1137               La Valse d'Amélie      yann tiersen       instrumental
# 19                             primo              高木正勝            ambient
# 1302   Prelude for Piano and Malaria        worrytrain            ambient
# 26940                 Melody of Love      billy vaughn       instrumental
# 29630                        :D/S/R:        ad hominem        black metal
# 19748                       Yamagata          hakobune            ambient
# 9719              Bad News From Home      randy newman  singer-songwriter
# 28185       Poverty And Its Opposite    arve henriksen               jazz
# 5282                         Reprise    the communards                80s
#
#       playcount    rank  danceability energy     key loudness  liveness  \
# 2006      17835  0.1870        0.0918      2 -18.018        1    0.1070
# 1137    2406694  0.1940        0.1790      9 -16.836        0    0.1790
# 19        33940  0.2250        0.0614      8 -22.935        1    0.1210
# 1302      59053  0.2180        0.0659     10 -23.204        1    0.1140
# 26940     17703  0.1930        0.0845      5 -26.860        1    0.1000
# 29630      3442  0.0995        0.1120      5 -20.770        0    0.0857
# 19748      7159  0.1360        0.1220      6 -31.151        1    0.0944
# 9719       8497  0.3150        0.0570      5 -16.554        0    0.2680
# 28185     29259  0.2830        0.1400      8 -24.394        0    0.3180
# 5282       9014  0.2690        0.1400     10 -14.959        0    0.2140
#
#        valence
# 2006    93.328
# 1137   177.667
# 19      77.384
# 1302    68.574
# 26940   82.151
# 29630   81.578
# 19748  142.797
# 9719   180.342
# 28185  113.882
# 5282    74.150

# %% [markdown]
# # To Do
#
# Normalize Valence, Energy, and Key
#
# Evaluate Performance
