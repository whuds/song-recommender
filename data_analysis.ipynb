# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
lastfm_tracks = pd.read_csv('data/lastfm_tracks.csv')

# %%
before_count = lastfm_tracks.shape[0]

# %%
tracks_dedup = lastfm_tracks.drop_duplicates()

# %%
tracks_dedup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3746602 entries, 0 to 3749938
# Data columns (total 5 columns):
# name           object
# tag_name       object
# playcount      int64
# listeners      int64
# artist_name    object
# dtypes: int64(2), object(3)
# memory usage: 171.5+ MB

# %%
after_count = tracks_dedup.shape[0]

# %%
print("Duplicate count: {}".format(before_count - after_count))
# Out:
# Duplicate count: 3337

# %%
features = pd.read_csv('data/spotify_audio_features.csv')

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829226 entries, 0 to 829225
# Data columns (total 24 columns):
# name                829222 non-null object
# tag_name            829226 non-null object
# playcount           829226 non-null int64
# listeners           829226 non-null int64
# artist_name         829226 non-null object
# rank                829226 non-null float64
# danceability        829226 non-null float64
# energy              829226 non-null int64
# key                 829226 non-null float64
# loudness            829226 non-null int64
# mode                829226 non-null float64
# speechiness         829226 non-null float64
# acousticness        829226 non-null float64
# instrumentalness    829226 non-null float64
# liveness            829226 non-null float64
# valence             829226 non-null float64
# tempo               829226 non-null object
# type                829226 non-null object
# id                  829226 non-null object
# ...

# %%
features.head()
# Out:
#                                      name tag_name  playcount  listeners  \
# 0                                 M.M.I.X     rock     165690      26280
# 1                                     Èkó     rock      85306      26100
# 2                             Old Friends     rock      82520      26026
# 3            Everything's Not Lost (live)     rock      77350      25802
# 4  Adventure Of A Lifetime - Matoma Remix     rock      74041      25720
#
#   artist_name   rank  danceability  energy     key  loudness  ...  liveness  \
# 0    Coldplay  0.175        0.0613       4 -29.286         1  ...    0.1570
# 1    Coldplay  0.341        0.3650       7 -13.871         1  ...    0.0486
# 2    Coldplay  0.477        0.1800       5 -17.499         1  ...    0.2360
# 3    Coldplay  0.282        0.4240       9  -9.012         1  ...    0.0505
# 4    Coldplay  0.651        0.7710       9  -6.541         0  ...    0.4560
#
#    valence           tempo                    type  \
# ...

# %%
before_count = features.shape[0]
features_dedup = features.drop_duplicates()
after_count = features_dedup.shape[0]
print("Duplicates: {}".format(before_count - after_count))
# Out:
# Duplicates: 1590

# %%
features_dedup = features_dedup.drop(columns=['time_signature'])

# %%
features_dedup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 827636 entries, 0 to 829225
# Data columns (total 23 columns):
# name                827632 non-null object
# tag_name            827636 non-null object
# playcount           827636 non-null int64
# listeners           827636 non-null int64
# artist_name         827636 non-null object
# rank                827636 non-null float64
# danceability        827636 non-null float64
# energy              827636 non-null int64
# key                 827636 non-null float64
# loudness            827636 non-null int64
# mode                827636 non-null float64
# speechiness         827636 non-null float64
# acousticness        827636 non-null float64
# instrumentalness    827636 non-null float64
# liveness            827636 non-null float64
# valence             827636 non-null float64
# tempo               827636 non-null object
# type                827636 non-null object
# id                  827636 non-null object
# ...

# %%
features_dedup.head()
# Out:
#                                      name tag_name  playcount  listeners  \
# 0                                 M.M.I.X     rock     165690      26280
# 1                                     Èkó     rock      85306      26100
# 2                             Old Friends     rock      82520      26026
# 3            Everything's Not Lost (live)     rock      77350      25802
# 4  Adventure Of A Lifetime - Matoma Remix     rock      74041      25720
#
#   artist_name   rank  danceability  energy     key  loudness  ...  \
# 0    Coldplay  0.175        0.0613       4 -29.286         1  ...
# 1    Coldplay  0.341        0.3650       7 -13.871         1  ...
# 2    Coldplay  0.477        0.1800       5 -17.499         1  ...
# 3    Coldplay  0.282        0.4240       9  -9.012         1  ...
# 4    Coldplay  0.651        0.7710       9  -6.541         0  ...
#
#    instrumentalness  liveness  valence           tempo  \
# 0             0.095    0.1570  126.842  audio_features
# ...

# %%
pd.Series.value_counts(features_dedup['tag_name'])
# Out:
# jazz                 51007
# ambient              42171
# punk                 41213
# rock                 39720
# seen live            39224
# Progressive rock     38645
# folk                 38402
# singer-songwriter    38340
# pop                  36845
# indie                36410
# 80s                  35552
# female vocalists     35463
# electronic           34682
# classic rock         34279
# dance                32323
# instrumental         32140
# experimental         32099
# black metal          30764
# death metal          29229
# Hip-Hop              28363
# indie rock           27279
# alternative rock     26701
# alternative          25813
# metal                19217
# hard rock             1755
# Name: tag_name, dtype: int64

# %%
print("Unique artists: {}".format(pd.Series.value_counts(features_dedup['artist_name']).shape[0]))
# Out:
# Unique artists: 6829

# %% [markdown]
# ## Important features
# * playcount (int)
# * tag_name (label encoded to int)
# * listeners (int)
# * danceability (float)[0-1]
# * energy (float) [0-1]
# * key (float)
# * loudness
# * mode
# * speechiness
# * acousticness
# * instrumentalness
# * liveness
# * valence
# * tempo
